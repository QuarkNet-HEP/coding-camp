# %% [markdown]
# <a href="https://colab.research.google.com/github/Peter-Apps/coding-camp/blob/main/Star_Locations_and_How_to_Start_Using_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Star catalogue analysis
# Your task is to:
# - analyze a huge collection of Hipparcos, Yale Bright Star, and Gliese catalogues
# - create a Hertzsprung-Russell diagram, and make changes to the plot style so that it better mimics the "classic" appearance of the H-R diagram
# - learn to analzye the data using code

# %% [markdown]
# # What is Colab? How does it work? Why do I have to do it?
# Google Colaboratory is a web-based program that allows us to write and execute code in the Python programming language. (Fun fact, Python is not named after the snake, but Monty Python's Flying Circus. The more you know.)
#
# There are two types of editors in Colab. The first is a text box. Like this. You can type text and your computer will ignore everything in the box when it runs your code. The second is a code box. This is where you type the code for the computer to read.
#
# Because I said so. Just kidding. Sort of. Coding is not just a skill that can open doors, it is a way of thinking that allows you to make sense of the things around you.

# %% [markdown]
# # Step 1 Importing Libraries
# Colab doesn't really have much in the way of functions in and of itself, but it allows you to import many different coding libraries. These libraries are essentially software packages the allow you to perform different functions within your program.

# %%
# Import modules
# You will at least need pandas, numpy, matplotlib, and pyplot
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # What does all of this mean?
#
# ![link text](https://alansimpson.me/python/cheatsheets/pandasbasics/pandasbasics256.jpg)
#
# `import pandas as pd`
#
#   **pandas** is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language
# # [pandas Documentation](https://pandas.pydata.org/docs/user_guide/index.html)
#
# ![link text](https://res.cloudinary.com/crunchbase-production/image/upload/c_lpad,h_256,w_256,f_auto,q_auto:eco/gxgj1nsz0eq3rg13j7kk)
#
# `import numpy as np`
#
#   **numpy** is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays.
# # [numpy Documentation](https://numpy.org/doc/stable/)
#
# ![link text](https://upload.wikimedia.org/wikipedia/commons/0/01/Created_with_Matplotlib-logo.svg)
# ```
# import matplotlib as mpl
# import matplotlib.pyplot as plt
# ```
#  **matplotlib** is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications
#
# # [matplotlib Documentation](https://matplotlib.org/stable/contents.html)
#
# **This section has been shamelessly stolen from Brian Burcham's energy colab. Thanks Brian!**

# %% [markdown]
# **Learning Check!**
#
# Notice that we are importing each library as something else. Why do you think we are doing that?

# %% [markdown]
# # Step 2 Importing Data
# In order to analyze data, we need data.

# %%
#Read in data that will be used for the calculations.
#Get the "stars.csv" in the "data" folder at https://github.com/adamlamee/CODINGinK12
data = pd.read_csv("https://github.com/adamlamee/CODINGinK12/raw/master/data/stars.csv")

# %% [markdown]
# **Learning Check!**
#
# Look closely at that line of code.
#
# What does each word tell the computer?
#
# Which library are we using to read the data?

# %% [markdown]
# #Step 3 Viewing Data
# Obviously, there are a LOT of stars. That means there is a lot of data that we need to sift through.

# %%
# The .shape command displays the (number of rows , number of columns) in a file.
data.shape
# Out:
# (119614, 16)

# %% [markdown]
# **Learning Check!**
#
# Looking at the result of the .shape function, how many stars are we analyzing?
# How many properties are we studying?

# %% [markdown]
# We could let the computer print the entire data table for us to look at. That doesn't seem like a good plan.

# %%
# We wish to look at the first 5 rows of our data set
data.head(5)
# Out:
#              proper         ra        dec    dist    mag  absmag     ci  \
# 0               Sol   0.000000   0.000000  0.0000 -26.70   4.850  0.656
# 1  Proxima Centauri  14.495985 -62.679485  1.2959  11.01  15.447  1.807
# 2   Rigil Kentaurus  14.660765 -60.833976  1.3248  -0.01   4.379  0.710
# 3               NaN  14.660346 -60.838300  1.3248   1.35   5.739  0.900
# 4    Barnard's Star  17.963472   4.693388  1.8238   9.54  13.235  1.570
#
#           temp         x         y         z  con       lum    var  var_min  \
# 0  5756.588113  0.000005  0.000000  0.000000  NaN  1.000000    NaN      NaN
# 1  3383.441193 -0.472264 -0.361451 -1.151219  Cen  0.000058   V645   11.079
# 2  5567.728737 -0.495203 -0.414084 -1.156625  Cen  1.543121    NaN    0.113
# 3  4996.415833 -0.495181 -0.413973 -1.156674  Cen  0.440961    NaN      NaN
# 4  3691.168543 -0.017373 -1.816613  0.149123  Oph  0.000443  V2500    9.590
#
#    var_max
# 0      NaN
# 1   10.939
# 2   -0.087
# 3      NaN
# 4    9.490

# %% [markdown]
# **Learning Check!**
#
# What does the data.head command do?
#
# What is the purpose of the (5)?
#
# Change the number to something else and rerun to see what happens.

# %% [markdown]
# #Step 4 Graphing Data
# Let's start with a scatter plot of some of this data.
#
# Take a second and look at each individual line of code below. Double click here and write one sentence to describe what each line is doing before running the code.

# %%
fig = plt.figure(figsize=(15, 4))
plt.scatter(data['ra'],data['dec'], s=0.01)
plt.xlim(24, 0)
plt.title("title?")
plt.xlabel("Label me!")
plt.ylabel("Me, too!");

# %% [markdown]
# **Learning Check!**
#
# - What are you seeing in this graph? The graph above shows declination vs. right ascension for each star in the data table.
#
# - What does each dot represent?
#
# -The title and axis labels on the graph could use some work. Try editing the code above the graph, then run the code again to see the changes.
#
# -Play around with the numbers and rerun the code to see how the graph changes.
#
# -What pattern do you see in the graph? What might explain that pattern?
#
# -Where would you find the stars in your constellation?

# %%
# Find the abbreviation for your constellation
data['con'].sort_values().unique()
# Out:
# array(['And', 'Ant', 'Aps', 'Aql', 'Aqr', 'Ara', 'Ari', 'Aur', 'Boo',
#        'CMa', 'CMi', 'CVn', 'Cae', 'Cam', 'Cap', 'Car', 'Cas', 'Cen',
#        'Cep', 'Cet', 'Cha', 'Cir', 'Cnc', 'Col', 'Com', 'CrA', 'CrB',
#        'Crt', 'Cru', 'Crv', 'Cyg', 'Del', 'Dor', 'Dra', 'Equ', 'Eri',
#        'For', 'Gem', 'Gru', 'Her', 'Hor', 'Hya', 'Hyi', 'Ind', 'LMi',
#        'Lac', 'Leo', 'Lep', 'Lib', 'Lup', 'Lyn', 'Lyr', 'Men', 'Mic',
#        'Mon', 'Mus', 'Nor', 'Oct', 'Oph', 'Ori', 'Pav', 'Peg', 'Per',
#        'Phe', 'Pic', 'PsA', 'Psc', 'Pup', 'Pyx', 'Ret', 'Scl', 'Sco',
#        'Sct', 'Ser', 'Sex', 'Sge', 'Sgr', 'Tau', 'Tel', 'TrA', 'Tri',
#        'Tuc', 'UMa', 'UMi', 'Vel', 'Vir', 'Vol', 'Vul', nan], dtype=object)

# %%
# Sort the data set according your constellation
myconstellation = data.query('con == "Cyg"') # I'm looking for the stars in Cygnus
plt.close('all')
fig = plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)

# Plot the stars in your constellation
plt.scatter(myconstellation['ra'],myconstellation['dec'])
plt.gca().invert_xaxis()
plt.title("A constellation in the sky")
plt.xlabel("right ascension")
plt.ylabel("declination")
# Out:
# Text(0, 0.5, 'declination')

# %% [markdown]
# **Learning Check!**
#
# That is a lot of stars...why does it not look like the constellation you see in the sky?
#
# The good news is we can sort out some of the data. Start with the 20 brightest stars. Play around with that sort function until you see your constellation.

# %%
# Sort the data set according your constellation
myconstellation = data.query('con == "Cyg"') # I'm looking for the stars in Cygnus
plt.close('all')
fig = plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)

# Plot the stars in your constellation
myconstellation = myconstellation.sort_values('mag').head(6)

plt.scatter(myconstellation['ra'],myconstellation['dec'])
plt.gca().invert_xaxis()
plt.title("A constellation in the sky")
plt.xlabel("right ascension")
plt.ylabel("declination")
# Out:
# Text(0, 0.5, 'declination')

# %% [markdown]
# Now overlay your constellation on to the big map.

# %%
#Sort by your constellation
myconstellation = data.query('con == "Cyg"') # I'm looking for the stars in Cygnus
plt.close('all')
fig = plt.figure(figsize=(30, 5))
plt.subplot(1, 2, 1)

# Plot the stars in your constellation onto the big plot
myconstellation = myconstellation.sort_values('mag').head(6)
plt.scatter(data['ra'],data['dec'], s=0.01) #Plot all of the stars

plt.scatter(myconstellation['ra'],myconstellation['dec'])
plt.title("A constellation in the sky")
plt.xlabel("right ascension")
plt.ylabel("declination")
# Out:
# Text(0, 0.5, 'declination')

# %% [markdown]
# **Learning Check!**
#
# -Are the orange dots arranged how you would have expected? Why or why not?
#
# -What could we do to make the arrangement more representative to what we see in the sky?

# %% [markdown]
# **Challenge**
# - Add our Sun to the plot.

# %% [markdown]
# ## Credits
# The data came from [The Astronomy Nexus](http://www.astronexus.com/hyg) and their collection of the Hipparcos, Yale Bright Star, and Gliese catalogues ([huge zip file here](http://www.astronexus.com/files/downloads/hygdata_v3.csv.gz)).
#
# The backbone of this activity came from Adam LaMee. Modification and additions by Tracie Schroeder.
